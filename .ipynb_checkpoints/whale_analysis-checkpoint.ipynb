# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data.

# %%
# Reading whale returns
whale_returns_csv_path = Path("whale_returns.csv")
whale_returns_df = pd.read_csv(whale_returns_csv_path, index_col="Date", infer_datetime_format=True, parse_dates=True)
whale_returns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_returns_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns_df.dropna(inplace=True)

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data.

# %%
# Reading algorithmic returns
algo_returns_csv_path = Path("algo_returns.csv")
algo_returns_df = pd.read_csv(algo_returns_csv_path, index_col="Date", infer_datetime_format=True, parse_dates=True)
algo_returns_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_returns_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns_df.dropna(inplace=True)

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Prices
sp_tsx_history_csv_path = Path("sp_tsx_history.csv")
sp_tsx_history_df = pd.read_csv(sp_tsx_history_csv_path, index_col="Date", infer_datetime_format=True, parse_dates=True)
sp_tsx_history_df.head()
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99

# %%
# Check Data Types
sp_tsx_history_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Rename `Close` Column to be specific to this portfolio.
sp_tsx_history_df = sp_tsx_history_df.rename(columns={"Close": "sp_tsx_history"}).copy()
sp_tsx_history_df
# Out:
#            sp_tsx_history
# Date
# 2012-10-01     $12,370.19
# 2012-10-02     $12,391.23
# 2012-10-03     $12,359.47
# 2012-10-04     $12,447.68
# 2012-10-05     $12,418.99
# ...                   ...
# 2019-12-20     $17,118.44
# 2019-12-23     $17,128.71
# 2019-12-24     $17,180.15
# 2019-12-27     $17,168.21
# 2019-12-30     $17,098.56
#
# [1818 rows x 1 columns]

# %%
# Fix Data Types
sp_tsx_history_df['sp_tsx_history'] = sp_tsx_history_df['sp_tsx_history'].str.replace('$', '')
sp_tsx_history_df['sp_tsx_history'] = sp_tsx_history_df['sp_tsx_history'].str.replace(',', '')
sp_tsx_history_df['sp_tsx_history'] = sp_tsx_history_df['sp_tsx_history'].astype('float')
sp_tsx_history_df.dtypes
# Out:
# C:\Users\lesli\AppData\Local\Temp\ipykernel_3940\126029213.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   sp_tsx_history_df['sp_tsx_history'] = sp_tsx_history_df['sp_tsx_history'].str.replace('$', '')
# sp_tsx_history    float64
# dtype: object

# %%
# Calculate Daily Returns
sp_tsx_history_df_daily_returns= sp_tsx_history_df.pct_change()
sp_tsx_history_df_daily_returns.head()
# Out:
#             sp_tsx_history
# Date
# 2012-10-01             NaN
# 2012-10-02        0.001701
# 2012-10-03       -0.002563
# 2012-10-04        0.007137
# 2012-10-05       -0.002305

# %%
# Drop nulls
sp_tsx_history_df_daily_returns=sp_tsx_history_df_daily_returns.dropna().copy()
sp_tsx_history_df_daily_returns.head()
# Out:
#             sp_tsx_history
# Date
# 2012-10-02        0.001701
# 2012-10-03       -0.002563
# 2012-10-04        0.007137
# 2012-10-05       -0.002305
# 2012-10-09       -0.011709

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
combined_df = pd.concat([whale_returns_df, algo_returns_df, sp_tsx_history_df_daily_returns], axis="columns", join="inner")
#combined_df = pd.concat([combined_df, sp_tsx_history_df_daily_returns.reset_index()], axis="columns", join="inner")
combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  sp_tsx_history
# Date
# 2015-03-03 -0.000949       -0.008530
# 2015-03-04  0.002416       -0.003371
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_df.plot(figsize=(20,10), title="Daily returns")
# Out:
# <AxesSubplot:title={'center':'Daily returns'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1 +combined_df).cumprod()
cumulative_returns.head()
# Plot cumulative returns
cumulative_returns.plot(figsize=(20,10), title="cumulative returns")
# Out:
# <AxesSubplot:title={'center':'cumulative returns'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios.
# 4. Determine which portfolios are riskier than the S&P TSX 60.
# 5. Calculate the Annualized Standard Deviation.

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_df.plot.box(figsize=(20,10), title="show combined risk")
# Out:
# <AxesSubplot:title={'center':'show combined risk'}>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
combined_df.std()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007828
# PAULSON & CO.INC.              0.006982
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# Algo 1                         0.007589
# Algo 2                         0.008326
# sp_tsx_history                 0.007034
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Calculate  the daily standard deviation of S&P TSX 60
SP_TSX_History_deviation = combined_df["sp_tsx_history"].std()

combined_df.std() > SP_TSX_History_deviation
# Out:
# SOROS FUND MANAGEMENT LLC       True
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                          True
# Algo 2                          True
# sp_tsx_history                 False
# dtype: bool

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
combined_df_annualized_deviation = combined_df.std()*np.sqrt(252)
combined_df_annualized_deviation
# Out:
# SOROS FUND MANAGEMENT LLC      0.124259
# PAULSON & CO.INC.              0.110841
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# BERKSHIRE HATHAWAY INC         0.203599
# Algo 1                         0.120470
# Algo 2                         0.132177
# sp_tsx_history                 0.111664
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for for all portfolios using a 21-day window.
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60.
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta for it and the S&P TSX 60.

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
combined_df_std_roll=combined_df.rolling(window=21).std()

# Plot the rolling standard deviation
combined_df_std_roll.plot(figsize=(20,10), title="Standard deviation for all portfolios 21-day window")
# Out:
# <AxesSubplot:title={'center':'Standard deviation for all portfolios 21-day window'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
combined_df_correlation = combined_df.corr() 
# Display de correlation matrix
combined_df_correlation.plot(figsize=(20,10), title="Standard deviation for all portfolios 21-day window")
# Out:
# <AxesSubplot:title={'center':'Standard deviation for all portfolios 21-day window'}>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
# Calculate covariance of a single portfolio

algo_returns_df_covariance = combined_df['BERKSHIRE HATHAWAY INC'].rolling(window=60).cov(combined_df['sp_tsx_history'])

# Calculate variance of S&P TSX
sp_tsx_history_variance = combined_df['sp_tsx_history'].rolling(window=60).var()

# Computing beta
BERKSHIRE_HATHAWAY_INC_beta = algo_returns_df_covariance / sp_tsx_history_variance

# Plot beta trend
BERKSHIRE_HATHAWAY_INC_beta.plot(figsize=(20, 10), title='BERKSHIRE HATHAWAY')
# Out:
# <AxesSubplot:title={'center':'BERKSHIRE HATHAWAY'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window

combined_df_ewm = combined_df.ewm(halflife=21).std()
combined_df_ewm.plot(figsize=(20,10), title="Standard deviation for all portfolios 21-day ewm")
# Out:
# <AxesSubplot:title={'center':'Standard deviation for all portfolios 21-day ewm'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# #In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios_combined_df = (combined_df.mean() * 252) / (combined_df.std() * np.sqrt(252))
sharpe_ratios_combined_df
# Out:
# SOROS FUND MANAGEMENT LLC      0.286709
# PAULSON & CO.INC.             -0.547594
# TIGER GLOBAL MANAGEMENT LLC   -0.144455
# BERKSHIRE HATHAWAY INC         0.467045
# Algo 1                         1.491514
# Algo 2                         0.396817
# sp_tsx_history                 0.195550
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios_combined_df.plot.bar(figsize=(20, 10), title='sharpe_ratios_combined_df')
# Out:
# <AxesSubplot:title={'center':'sharpe_ratios_combined_df'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# The algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios ????

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock.
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns.
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others.
# 5. Include correlation analysis to determine which stocks (if any) are correlated.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
otex_historical_path = Path("otex_historical.csv")
otex_historical_df = pd.read_csv(otex_historical_path, index_col="Date", infer_datetime_format=True, parse_dates=True)
otex_historical_df.head()
# Out:
#            Symbol  Close
# Date
# 2018-01-02   OTEX  43.58
# 2018-01-03   OTEX  43.07
# 2018-01-04   OTEX  42.91
# 2018-01-05   OTEX  42.57
# 2018-01-08   OTEX  42.16

# %%
# Reading data from 2nd stock
shop_historical_path = Path("shop_historical.csv")
shop_historical_df = pd.read_csv(shop_historical_path, index_col="Date", infer_datetime_format=True, parse_dates=True)
shop_historical_df.head()
# Out:
#            Symbol   Close
# Date
# 2018-01-02   SHOP  132.06
# 2018-01-03   SHOP  135.15
# 2018-01-04   SHOP  137.46
# 2018-01-05   SHOP  137.26
# 2018-01-08   SHOP  139.51

# %%
# Reading data from 3rd stock
l_historical_path = Path("l_historical.csv")
l_historical_df = pd.read_csv(l_historical_path, index_col="Date", infer_datetime_format=True, parse_dates=True)

l_historical_df.head()
# Out:
#            Symbol  Close
# Date
# 2018-01-02      L  57.99
# 2018-01-03      L  57.41
# 2018-01-04      L  57.42
# 2018-01-05      L  57.42
# 2018-01-08      L  56.86

# %%
# Combine all stocks in a single DataFrame
custom_combined_df = pd.concat([otex_historical_df.Close, shop_historical_df.Close, l_historical_df.Close], axis="columns", join="inner")
custom_combined_df.head(5)
# Out:
#             Close   Close  Close
# Date
# 2018-01-02  43.58  132.06  57.99
# 2018-01-03  43.07  135.15  57.41
# 2018-01-04  42.91  137.46  57.42
# 2018-01-05  42.57  137.26  57.42
# 2018-01-08  42.16  139.51  56.86

# %%
# Reset Date index

# %%
# Reorganize portfolio data by having a column per symbol
custom_combined_df.columns = ["otex","shop","l"]
custom_combined_df
# Out:
#              otex    shop      l
# Date
# 2018-01-02  43.58  132.06  57.99
# 2018-01-03  43.07  135.15  57.41
# 2018-01-04  42.91  137.46  57.42
# 2018-01-05  42.57  137.26  57.42
# 2018-01-08  42.16  139.51  56.86
# ...           ...     ...    ...
# 2019-12-20  58.68  513.22  67.90
# 2019-12-23  57.89  511.62  67.68
# 2019-12-24  57.44  525.39  67.67
# 2019-12-27  57.70  534.76  67.78
# 2019-12-30  57.19  517.79  67.33
#
# [501 rows x 3 columns]

# %%
# Calculate daily returns
custom_daily_returns = custom_combined_df.pct_change()

# Drop NAs
custom_daily_returns = custom_daily_returns.dropna()


# Display sample data
custom_daily_returns
# Out:
#                 otex      shop         l
# Date
# 2018-01-03 -0.011703  0.023398 -0.010002
# 2018-01-04 -0.003715  0.017092  0.000174
# 2018-01-05 -0.007924 -0.001455  0.000000
# 2018-01-08 -0.009631  0.016392 -0.009753
# 2018-01-09 -0.000712 -0.011254  0.008969
# ...              ...       ...       ...
# 2019-12-20  0.024441 -0.005503  0.003547
# 2019-12-23 -0.013463 -0.003118 -0.003240
# 2019-12-24 -0.007773  0.026915 -0.000148
# 2019-12-27  0.004526  0.017834  0.001626
# 2019-12-30 -0.008839 -0.031734 -0.006639
#
# [500 rows x 3 columns]

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
custom_daily_returns = custom_daily_returns.dot(weights)

# Display sample data
custom_daily_returns.head()
# Out:
# Date
# 2018-01-03    0.000565
# 2018-01-04    0.004517
# 2018-01-05   -0.003126
# 2018-01-08   -0.000997
# 2018-01-09   -0.000999
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
custom_combined_df_combined_df = pd.concat([custom_combined_df, combined_df], axis="columns", join="inner")
custom_combined_df_combined_df.head(5)
# Out:
#              otex    shop      l  SOROS FUND MANAGEMENT LLC  \
# Date
# 2018-01-02  43.58  132.06  57.99                   0.014546
# 2018-01-03  43.07  135.15  57.41                   0.004658
# 2018-01-04  42.91  137.46  57.42                  -0.000914
# 2018-01-05  42.57  137.26  57.42                   0.004072
# 2018-01-08  42.16  139.51  56.86                   0.004473
#
#             PAULSON & CO.INC.   TIGER GLOBAL MANAGEMENT LLC  \
# Date
# 2018-01-02            0.015045                    -0.004784
# 2018-01-03            0.000027                     0.001979
# 2018-01-04            0.004196                     0.010743
# 2018-01-05            0.000823                     0.000737
# 2018-01-08           -0.003739                     0.005085
#
#             BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  sp_tsx_history
# Date
# 2018-01-02                0.031017  0.001254  0.017222        0.006222
# 2018-01-03                0.005676 -0.000890  0.008175        0.003774
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
custom_combined_df_combined_df = custom_combined_df_combined_df.dropna()
custom_combined_df_combined_df.head()
# Out:
#              otex    shop      l  SOROS FUND MANAGEMENT LLC  \
# Date
# 2018-01-02  43.58  132.06  57.99                   0.014546
# 2018-01-03  43.07  135.15  57.41                   0.004658
# 2018-01-04  42.91  137.46  57.42                  -0.000914
# 2018-01-05  42.57  137.26  57.42                   0.004072
# 2018-01-08  42.16  139.51  56.86                   0.004473
#
#             PAULSON & CO.INC.   TIGER GLOBAL MANAGEMENT LLC  \
# Date
# 2018-01-02            0.015045                    -0.004784
# 2018-01-03            0.000027                     0.001979
# 2018-01-04            0.004196                     0.010743
# 2018-01-05            0.000823                     0.000737
# 2018-01-08           -0.003739                     0.005085
#
#             BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  sp_tsx_history
# Date
# 2018-01-02                0.031017  0.001254  0.017222        0.006222
# 2018-01-03                0.005676 -0.000890  0.008175        0.003774
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
custom_combined_dfannualized_std = custom_combined_df.std() * np.sqrt(252)

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
custom_combined_df_std_roll = custom_combined_df.rolling(window=21).std()

# Plot the rolling standard deviation
custom_combined_df_std_roll.plot(figsize=(20,10), title="Standard deviation for custom portfolio 21-day window")
# Out:
# <AxesSubplot:title={'center':'Standard deviation for custom portfolio 21-day window'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
custom_combined_df_correlation = custom_combined_df.corr() 
# Display de correlation matrix
custom_combined_df_correlation.plot(figsize=(20,10), title="Correlation for custom portfolio 21-day window")
# Out:
# <AxesSubplot:title={'center':'Correlation for custom portfolio 21-day window'}>

# %% [markdown]
# ### Calculate and Plot the 60-day Rolling Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate and plot Beta ?????

custom_combined_df_covariance = custom_combined_df.rolling(window=60).cov()

custom_combined_df_beta = custom_combined_df_covariance / sp_tsx_history_variance

custom_combined_df_beta.plot(figsize=(20, 10), title='60-day Rolling Beta for Custom')
# Out:
# <AxesSubplot:title={'center':'60-day Rolling Beta for Custom'}, xlabel='Date,None'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
# Annualized Sharpe Ratios
sharpe_ratios_custom_combined_df = (custom_combined_df.mean() * 252) / (custom_combined_df.std() * np.sqrt(252))
sharpe_ratios_custom_combined_df
# Out:
# otex    172.208435
# shop     37.439396
# l       153.128206
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios_custom_combined_df.plot.bar(figsize=(20, 10), title='sharpe_ratios_combined_df')
# Out:
# <AxesSubplot:title={'center':'sharpe_ratios_combined_df'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!
